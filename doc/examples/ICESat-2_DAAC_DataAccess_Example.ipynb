# %% [markdown]
# ## Accessing ICESat-2 Data
# ### Data Query and Download Example Notebook
# This notebook illustrates the use of icepyx for ICESat-2 data access and download from the NASA NSIDC DAAC (NASA National Snow and Ice Data Center Distributed Active Archive Center).
#
# #### Credits
# * notebook by: Jessica Scheick
# * source material: [NSIDC Data Access Notebook](https://github.com/ICESAT-2HackWeek/ICESat2_hackweek_tutorials/tree/master/03_NSIDCDataAccess_Steiker) by Amy Steiker and Bruce Wallin

# %% [markdown]
# ### Import packages, including icepyx

# %%
#from icepyx import is2class as ipd
import os
import shutil
# %matplotlib inline

# %%
# %cd ./../
# Out:
# /home/jovyan/icepyx

# %%
# %load_ext autoreload
from icepyx import is2class as ipd
# %autoreload 2
#in order to use "as ipd", you have to use autoreload 2, which will automatically reload any module not excluded by being imported with %aimport -[module]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pwd
# Out:
# /home/jovyan/icepyx/doc/examples

# %% [markdown]
# ### Quick-Start
#
# The entire process of getting ICESat-2 data (from query to download) can ultimately be accomplished in three minimal lines of code:
#
# `region_a = ipd.Icesat2Data(short_name, spatial_extent, date_range)`
#
# `session=region_a.earthdata_login(earthdata_uid, email)`
#
# `region_a.download_granules(session, path)`
#
# **The rest of this notebook explains the required inputs used above, optional inputs not available in the minimal example, and the other data search and visualization tools built in to icepyx that make it easier for the user to find, explore, and download ICESat-2 data programmatically from NSIDC.** The detailed steps outlined and the methods showcased below are meant to give the user more control over the data they find and download (including options to download only the relevant portions of a data granule), many of which are called using default values behind the scenes if the user simply skips to the `download_granules` step.

# %% [markdown]
# ### Create an ICESat-2 data object with the desired search parameters
#
# There are three required inputs:
# - `short_name` = the dataset of interest, known as its "short name".
# See https://nsidc.org/data/icesat-2/data-sets for a list of the available datasets.
# - `spatial extent` = a region of interest to search within. This can be entered as a bounding box, polygon vertex coordinate pairs, or a polygon geospatial file (currently shp, kml, and gpkg are supported).
#     - bounding box: Given in decimal degrees for the lower left longitude, lower left latitude, upper right longitude, and upper right latitude
#     - polygon vertices: Given as longitude, latitude coordinate pairs of decimal degrees with the last entry a repeat of the first.
#     - polygon file: A string containing the full file path and name.
# - `date_range` = the date range for which you would like to search for results. Must be formatted as a set of 'YYYY-MM-DD' strings.
#
# Below are examples of each type of spatial extent input. Please choose and run only one.

# %%
#bounding box
short_name = 'ATL06'
spatial_extent = [-55, 68, -48, 71]
date_range = ['2019-02-22','2019-02-28']

# %%
#NOTE: currently a polygon generated using this block will not make it through the workflow.
#A bug report has been posted and work to correct the issue is ongoing.
#polygon vertices (here equivalent to the bounding box, above)
short_name = 'ATL06'
spatial_extent = [(-55, 68), (-55, 71), (-48, 71), (-48, 68), (-55, 68)]
date_range = ['2019-02-22','2019-02-28']

# %%
#polygon geospatial file
short_name = 'ATL06'
spatial_extent = './supporting_files/data-access_PineIsland/glims_polygons.kml'
date_range = ['2019-02-22','2019-02-28']

# %% [markdown]
# Create the data object using our inputs

# %%
region_a = ipd.Icesat2Data(short_name, spatial_extent, date_range)

# %% [markdown]
# Formatted parameters and function calls allow us to see the the properties of the data object we have created.

# %%
print(region_a.dataset)
print(region_a.dates)
print(region_a.start_time)
print(region_a.end_time)
print(region_a.dataset_version)
print(region_a.spatial_extent)
region_a.visualize_spatial_extent()
# Out:
# ATL06
# ['2019-02-22', '2019-02-28']
# 00:00:00
# 23:59:59
# 002
# ['bounding box', [-55, 68, -48, 71]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-f7caa8ce6448> in <module>
#       5 print(region_a.dataset_version)
#       6 print(region_a.spatial_extent)
# ----> 7 region_a.visualize_spatial_extent()
#
# ~/icepyx/icepyx/core/is2class.py in visualize_spatial_extent(self)
#    1353         f, ax = plt.subplots(1, figsize=(12, 6))
#    1354         world.plot(ax=ax, facecolor='lightgray', edgecolor='gray')
# -> 1355         self.geodataframe().plot(ax=ax, color='#FF8C00',alpha = '0.7')
#    1356         plt.show()
#    1357
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     654         from there.
#     655         """
# --> 656         return plot_dataframe(self, *args, **kwargs)
#     657
#     658     plot.__doc__ = plot_dataframe.__doc__
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/geopandas/plotting.py in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, classification_kwds, missing_kwds, **style_kwds)
#     538
#     539     if column is None:
# --> 540         return plot_series(
#     541             df.geometry,
#     542             cmap=cmap,
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, figsize, **style_kwds)
#     370
#     371         values_ = values[poly_idx] if cmap else None
# --> 372         plot_polygon_collection(
#     373             ax, polys, values_, facecolor=facecolor, cmap=cmap, **style_kwds
#     374         )
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/geopandas/plotting.py in plot_polygon_collection(ax, geoms, values, color, cmap, vmin, vmax, **kwargs)
#     118                         )
#     119
# --> 120     collection = PatchCollection([PolygonPatch(poly) for poly in geoms], **kwargs)
#     121
#     122     if values is not None:
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, patches, match_original, **kwargs)
#    1833             kwargs['antialiaseds'] = [p.get_antialiased() for p in patches]
#    1834
# -> 1835         Collection.__init__(self, **kwargs)
#    1836
#    1837         self.set_paths(patches)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     162
#     163         self._path_effects = None
# --> 164         self.update(kwargs)
#     165         self._paths = None
#     166
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#    1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
# -> 1003                 return func(v)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/collections.py in set_alpha(self, alpha)
#     770     def set_alpha(self, alpha):
#     771         # docstring inherited
# --> 772         super().set_alpha(alpha)
#     773         self.update_dict['array'] = True
#     774         self._set_facecolor(self._original_facecolor)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/matplotlib/artist.py in set_alpha(self, alpha)
#     930         """
#     931         if alpha is not None and not isinstance(alpha, Number):
# --> 932             raise TypeError('alpha must be a float or None')
#     933         self._alpha = alpha
#     934         self.pchanged()
#
# TypeError: alpha must be a float or None

# %% [markdown]
# There are also several optional inputs to allow the user finer control over their search.
# - `start_time` = start time to search for data on the start date. If no input is given, this defaults to 00:00:00.
# - `end_time` = end time for the end date of the temporal search parameter. If no input is given, this defaults to 23:59:59. Times must be input as 'HH:mm:ss' strings.
# - `version` = What version of the dataset to use, input as a numerical string. If no input is given, this value defaults to the most recent version of the dataset specified in `short_name`.

# %%
region_a = ipd.Icesat2Data(short_name, spatial_extent, date_range, \
                           start_time='03:30:00', end_time='21:30:00', version='001')

print(region_a.dataset)
print(region_a.dates)
print(region_a.start_time)
print(region_a.end_time)
print(region_a.dataset_version)
print(region_a.spatial_extent)
# Out:
# ATL06
# ['2019-02-22', '2019-02-28']
# 03:30:00
# 21:30:00
# 001
# ['bounding box', [-55, 68, -48, 71]]
# /home/jovyan/icepyx/icepyx/core/is2class.py:229: UserWarning: You are using an old version of this dataset
#   warnings.warn("You are using an old version of this dataset")

# %% [markdown]
# Alternatively, you can also just create the data object without creating named variables first.

# %%
region_a = ipd.Icesat2Data('ATL06',[-55, 68, -48, 71],['2019-02-01','2019-02-28'], \
                           start_time='00:00:00', end_time='23:59:59', version='002')

# %% [markdown]
# ### Built in methods allow us to get more information about our dataset
# In addition to viewing the stored object information shown above (e.g. dataset, start and end date and time, version, etc.), we can also request summary information about the dataset itself or confirm that we have manually specified the latest version.

# %%
region_a.dataset_summary_info()
print(region_a.latest_version())
# Out:
# dataset_id :  ATLAS/ICESat-2 L3A Land Ice Height V002
# short_name :  ATL06
# version_id :  002
# time_start :  2018-10-14T00:00:00.000Z
# coordinate_system :  CARTESIAN
# summary :  This data set (ATL06) provides geolocated, land-ice surface heights (above the WGS 84 ellipsoid, ITRF2014 reference frame), plus ancillary parameters that can be used to interpret and assess the quality of the height estimates. The data were acquired by the Advanced Topographic Laser Altimeter System (ATLAS) instrument on board the Ice, Cloud and land Elevation Satellite-2 (ICESat-2) observatory.
# orbit_parameters :  {'swath_width': '36.0', 'period': '94.29', 'inclination_angle': '92.0', 'number_of_orbits': '0.071428571', 'start_circular_latitude': '0.0'}
# 002

# %% [markdown]
# If the summary does not provide all of the information you are looking for, or you would like to see information for previous versions of the dataset, all available metadata for the collection dataset is available in a readable format.

# %%
region_a.dataset_all_info()
# Out:
# {'feed': {'entry': [{'archive_center': 'NASA NSIDC DAAC',
#                      'associations': {'services': ['S1568899363-NSIDC_ECS',
#                                                    'S1613689509-NSIDC_ECS',
#                                                    'S1613669681-NSIDC_ECS']},
#                      'boxes': ['-90 -180 90 180'],
#                      'browse_flag': False,
#                      'coordinate_system': 'CARTESIAN',
#                      'data_center': 'NSIDC_ECS',
#                      'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#                      'has_formats': True,
#                      'has_spatial_subsetting': True,
#                      'has_temporal_subsetting': True,
#                      'has_transforms': False,
#                      'has_variables': True,
#                      'id': 'C1511847675-NSIDC_ECS',
#                      'links': [{'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://openaltimetry.org/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.001',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.001',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'}],
#                      'online_access_flag': True,
#                      'orbit_parameters': {'inclination_angle': '92.0',
#                                           'number_of_orbits': '0.071428571',
#                                           'period': '94.29',
#                                           'start_circular_latitude': '0.0',
#                                           'swath_width': '36.0'},
#                      'organizations': ['NASA NSIDC DAAC',
#                                        'NASA/GSFC/EOS/ESDIS'],
#                      'original_format': 'ISO19115',
#                      'processing_level_id': 'Level 3',
#                      'short_name': 'ATL06',
#                      'summary': 'This data set (ATL06) provides geolocated, '
#                                 'land-ice surface heights (above the WGS 84 '
#                                 'ellipsoid, ITRF2014 reference frame), plus '
#                                 'ancillary parameters that can be used to '
#                                 'interpret and assess the quality of the '
#                                 'height estimates. The data were acquired by '
#                                 'the Advanced Topographic Laser Altimeter '
#                                 'System (ATLAS) instrument on board the Ice, '
#                                 'Cloud and land Elevation Satellite-2 '
#                                 '(ICESat-2) observatory.',
#                      'time_start': '2018-10-14T00:00:00.000Z',
#                      'title': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#                      'version_id': '001'},
#                     {'archive_center': 'NASA NSIDC DAAC',
#                      'associations': {'services': ['S1568899363-NSIDC_ECS',
#                                                    'S1613669681-NSIDC_ECS',
#                                                    'S1613689509-NSIDC_ECS']},
#                      'boxes': ['-90 -180 90 180'],
#                      'browse_flag': False,
#                      'coordinate_system': 'CARTESIAN',
#                      'data_center': 'NSIDC_ECS',
#                      'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V002',
#                      'has_formats': True,
#                      'has_spatial_subsetting': True,
#                      'has_temporal_subsetting': True,
#                      'has_transforms': False,
#                      'has_variables': True,
#                      'id': 'C1631076765-NSIDC_ECS',
#                      'links': [{'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.002/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1631076765-NSIDC_ECS&q=atl06%20v002&m=-113.62703547966265!-24.431396484375!0!1!0!0%2C2&tl=1556125020!4',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://openaltimetry.org/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.002',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.002',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'}],
#                      'online_access_flag': True,
#                      'orbit_parameters': {'inclination_angle': '92.0',
#                                           'number_of_orbits': '0.071428571',
#                                           'period': '94.29',
#                                           'start_circular_latitude': '0.0',
#                                           'swath_width': '36.0'},
#                      'organizations': ['NASA NSIDC DAAC',
#                                        'NASA/GSFC/EOS/ESDIS'],
#                      'original_format': 'ISO19115',
#                      'processing_level_id': 'Level 3',
#                      'short_name': 'ATL06',
#                      'summary': 'This data set (ATL06) provides geolocated, '
#                                 'land-ice surface heights (above the WGS 84 '
#                                 'ellipsoid, ITRF2014 reference frame), plus '
#                                 'ancillary parameters that can be used to '
#                                 'interpret and assess the quality of the '
#                                 'height estimates. The data were acquired by '
#                                 'the Advanced Topographic Laser Altimeter '
#                                 'System (ATLAS) instrument on board the Ice, '
#                                 'Cloud and land Elevation Satellite-2 '
#                                 '(ICESat-2) observatory.',
#                      'time_start': '2018-10-14T00:00:00.000Z',
#                      'title': 'ATLAS/ICESat-2 L3A Land Ice Height V002',
#                      'version_id': '002'}],
#           'id': 'https://cmr.earthdata.nasa.gov:443/search/collections.json?short_name=ATL06',
#           'title': 'ECHO dataset metadata',
#           'updated': '2020-02-24T18:20:27.740Z'}}

# %% [markdown]
# ### Querying a dataset
# In order to search the dataset collection for available data granules, we need to build our search parameters. These are formatted as a dictionary of key:value pairs according to the CMR documentation.

# %%
region_a.build_CMR_params()

# %%
#view the parameters that will be submitted in our query
region_a.CMRparams
# Out:
# {'short_name': 'ATL06',
#  'version': '002',
#  'temporal': '2019-02-22T00:00:00Z,2019-02-28T23:59:59Z',
#  'polygon': '-86.622742,-74.908126,-86.561712,-74.870913,-86.868859,-74.730522,-86.962905,-74.605038,-89.02594,-74.316754,-89.630517,-74.192147,-89.830808,-74.065919,-90.746478,-73.956258,-91.668214,-74.023169,-92.049815,-73.929387,-93.420791,-73.929327,-93.997163,-73.882768,-94.277701,-73.714183,-95.133017,-73.966355,-96.513501,-74.127404,-99.889802,-74.085347,-100.114438,-74.019422,-100.355131,-74.080906,-100.462734,-74.240864,-100.827076,-74.373988,-101.795349,-74.369597,-102.424826,-74.497263,-101.188725,-74.7179,-101.564382,-75.02971,-103.37484,-75.273725,-103.914847,-75.426057,-104.012128,-75.5223,-103.029452,-75.748774,-102.350567,-75.749245,-101.837882,-75.943066,-101.899461,-76.014086,-101.280944,-76.192769,-101.325735,-76.246168,-101.190803,-76.27106,-101.250474,-76.342292,-101.175067,-76.345822,-101.402436,-76.52035,-101.326063,-76.523929,-101.449791,-76.666392,-101.310795,-76.691373,-101.357407,-76.744819,-101.217404,-76.769752,-101.295133,-76.85887,-101.058051,-76.962123,-100.447336,-77.117686,-98.433698,-77.320866,-97.28308,-77.355688,-97.491148,-77.423178,-96.514174,-77.485919,-96.552494,-77.558236,-96.384656,-77.562336,-96.441516,-77.670857,-97.139363,-77.836566,-97.193451,-77.926901,-97.64271,-78.080044,-96.297869,-78.388943,-96.327803,-78.44329,-95.721466,-78.511065,-95.748962,-78.565482,-94.940425,-78.617072,-94.988611,-78.726066,-94.911669,-78.763976,-95.609268,-78.843079,-95.637038,-78.897535,-95.37191,-78.9391,-95.693408,-79.006456,-95.269903,-79.124145,-95.323729,-79.233172,-95.430206,-79.249633,-95.155505,-79.291032,-95.191045,-79.363748,-94.81352,-79.406486,-94.847075,-79.479253,-94.747448,-79.48078,-94.772403,-79.535367,-93.90411,-79.638844,-93.843651,-79.749409,-93.967323,-79.802836,-93.788723,-79.87821,-93.816393,-79.951128,-93.230546,-80.085534,-91.707475,-79.87748,-91.801545,-79.822143,-91.488897,-79.805457,-91.465152,-79.641131,-90.447349,-79.5894,-90.545492,-79.534464,-90.042319,-79.37062,-90.140775,-79.334083,-90.041814,-79.24285,-88.982186,-79.076903,-90.230262,-78.914333,-90.32191,-78.804808,-90.689626,-78.676516,-91.150024,-78.638589,-92.035347,-78.414844,-92.106013,-78.30491,-91.651645,-78.271472,-91.365784,-78.127206,-91.188783,-78.128018,-91.090167,-78.019109,-90.737076,-77.983849,-90.909191,-77.946905,-90.732603,-77.911009,-90.727088,-77.819973,-91.070502,-77.800626,-91.14118,-77.636469,-91.90279,-77.613923,-91.984627,-77.595116,-91.972963,-77.522365,-92.466819,-77.463587,-92.199521,-77.374914,-92.352136,-77.300761,-92.335283,-77.209895,-91.434206,-77.234653,-91.426015,-77.16193,-91.015545,-77.145686,-91.008355,-77.054784,-91.086397,-77.018096,-91.647835,-76.97871,-91.640906,-76.924199,-91.873848,-76.868024,-91.779021,-76.759619,-90.823937,-76.710073,-90.345113,-76.52953,-86.988029,-75.856983,-86.945563,-75.711143,-86.872234,-75.710165,-87.034102,-75.63967,-86.965004,-75.620616,-87.075115,-75.440545,-87.003154,-75.439609,-87.021872,-75.349129,-86.835058,-75.219586,-86.850654,-75.147247,-86.717729,-75.109052,-86.737771,-75.018662,-86.602149,-74.998483,-86.622742,-74.908126'}

# %% [markdown]
# Now that our parameter dictionary is constructed, we can search the CMR database for the available granules. Granules returned by the search are automatically stored within the data object.

# %%
#search for available granules
region_a.avail_granules()
# Out:
# {'Number of available granules': 3,
#  'Average size of granules (MB)': 46.62313429513333,
#  'Total size of all granules (MB)': 139.8694028854}

# %%
#print the information about the returned search results
region_a.granules
# Out:
# [{'producer_granule_id': 'ATL06_20190224014644_08800205_001_02.h5',
#   'time_start': '2019-02-24T01:46:44.000Z',
#   'orbit': {'ascending_crossing': '118.48823342351116',
#    'start_lat': '80',
#    'start_direction': 'D',
#    'end_lat': '59.5',
#    'end_direction': 'D'},
#   'updated': '2019-07-29T15:24:14.848Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2019-02-24T01:20:38.079Z',
#     'equator_crossing_longitude': '118.48823342351116',
#     'orbit_number': '2468'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:163362111',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2019-02-24T01:52:09.000Z',
#   'id': 'G1626612008-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '51.3712024689',
#   'browse_flag': True,
#   'polygons': [['80.11254119920325 -55.514517904891214 61.18421494056679 -65.31024196939337 59.5979414453054 -65.65802135334556 59.620288355717484 -66.29682109861751 61.20767873724507 -65.9808046158936 80.17859740110205 -57.36759397107679 80.11254119920325 -55.514517904891214']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.24/ATL06_20190224014644_08800205_001_02.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190224014644_08800205_001_02_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.24/ATL06_20190224014644_08800205_001_02.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20190225012105_08950205_001_02.h5',
#   'time_start': '2019-02-25T01:21:05.000Z',
#   'orbit': {'ascending_crossing': '124.19865116941538',
#    'start_lat': '80',
#    'start_direction': 'D',
#    'end_lat': '59.5',
#    'end_direction': 'D'},
#   'updated': '2019-07-29T15:49:17.860Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2019-02-25T00:54:59.083Z',
#     'equator_crossing_longitude': '124.19865116941538',
#     'orbit_number': '2483'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:163364100',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2019-02-25T01:26:30.000Z',
#   'id': 'G1626614827-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '38.9777641296',
#   'browse_flag': True,
#   'polygons': [['80.11254119920325 -49.80410015898697 61.18421494056679 -59.59982422348913 59.5979414453054 -59.94760360744134 59.620288355717484 -60.586403352713255 61.20767873724507 -60.270386869989366 80.17859740110205 -51.65717622517255 80.11254119920325 -49.80410015898697']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.25/ATL06_20190225012105_08950205_001_02.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190225012105_08950205_001_02_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.25/ATL06_20190225012105_08950205_001_02.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20190227125331_09330203_001_02.h5',
#   'time_start': '2019-02-27T12:53:31.000Z',
#   'orbit': {'ascending_crossing': '-53.3363311756948',
#    'start_lat': '59.5',
#    'start_direction': 'A',
#    'end_lat': '80',
#    'end_direction': 'A'},
#   'updated': '2019-07-29T13:47:03.968Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2019-02-27T12:38:00.093Z',
#     'equator_crossing_longitude': '-53.3363311756948',
#     'orbit_number': '2521'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:163356268',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2019-02-27T12:58:56.000Z',
#   'id': 'G1626604566-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '28.2628087997',
#   'browse_flag': True,
#   'polygons': [['59.17274605456974 -60.88703590955776 78.13634620123182 -68.8348145748147 79.69617085871715 -70.5688349158393 79.7595680989217 -68.78731728294447 78.19146334563216 -67.27848059537223 59.194814244220126 -60.25616625891974 59.17274605456974 -60.88703590955776']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.27/ATL06_20190227125331_09330203_001_02.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190227125331_09330203_001_02_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.27/ATL06_20190227125331_09330203_001_02.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20190228013825_09410205_001_02.h5',
#   'time_start': '2019-02-28T01:38:25.000Z',
#   'orbit': {'ascending_crossing': '117.70951648873519',
#    'start_lat': '80',
#    'start_direction': 'D',
#    'end_lat': '59.5',
#    'end_direction': 'D'},
#   'updated': '2019-07-29T16:21:37.700Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2019-02-28T01:12:19.202Z',
#     'equator_crossing_longitude': '117.70951648873519',
#     'orbit_number': '2529'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:163367114',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2019-02-28T01:43:50.000Z',
#   'id': 'G1626617641-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '53.0308160782',
#   'browse_flag': True,
#   'polygons': [['80.11254119920325 -56.293234839667164 61.18421494056679 -66.08895890416932 59.5979414453054 -66.43673828812153 59.620288355717484 -67.07553803339344 61.20767873724507 -66.75952155066956 80.17859740110205 -58.14631090585274 80.11254119920325 -56.293234839667164']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.28/ATL06_20190228013825_09410205_001_02.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228013825_09410205_001_02_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.28/ATL06_20190228013825_09410205_001_02.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20190228122752_09480203_001_02.h5',
#   'time_start': '2019-02-28T12:27:52.000Z',
#   'orbit': {'ascending_crossing': '-47.62606053384416',
#    'start_lat': '59.5',
#    'start_direction': 'A',
#    'end_lat': '80',
#    'end_direction': 'A'},
#   'updated': '2019-07-29T15:03:12.730Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2019-02-28T12:12:20.932Z',
#     'equator_crossing_longitude': '-47.62606053384416',
#     'orbit_number': '2536'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:163361528',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2019-02-28T12:33:17.000Z',
#   'id': 'G1626611152-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '27.0904788971',
#   'browse_flag': True,
#   'polygons': [['59.23620991503794 -55.18999383987056 78.19889658523051 -63.18571726592021 79.75836736125919 -64.93812634235209 79.82214785292517 -63.1462708388764 78.2543030606438 -61.621458421613426 59.258319186474864 -54.557955251514734 59.23620991503794 -55.18999383987056']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.28/ATL06_20190228122752_09480203_001_02.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.07.29/ATL06_20190228122752_09480203_001_02_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2019.02.28/ATL06_20190228122752_09480203_001_02.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]}]

# %% [markdown]
# ### Downloading the found granules
# In order to download any data from NSIDC, we must first authenticate ourselves using a valid Earthdata login. This will create a valid token to interface with the DAAC as well as start an active logged-in session to enable data download. The token is attached to the data object and stored, but the session must be passed to the download function. Passwords are entered but not shown or stored in plain text by the system (I think?)

# %%
earthdata_uid = ''
email = ''
session=region_a.earthdata_login(earthdata_uid, email)
# Out:
# Earthdata Login password:  ········

# %% [markdown]
# Once we have generated our session, we must build the required configuration parameters needed to actually download data. These will tell the system how we want to download the data.
# - `page_size` = 10. This is the number of granules we will request per order.
# - `page_num` = 1. Determine the number of pages based on page size and the number of granules available. If no page_num is specified, this calculation is done automatically to set page_num, which then provides the number of individual orders we will request given the number of granules.
# - `request_mode` = 'async'
# - `agent` = 'NO'
# - `include_meta` = 'Y'
#
# #### More details about the configuration parameters
# `request_mode` is "synchronous" by default, meaning that the request relies on a direct, continous connection between you and the API endpoint. Outputs are directly downloaded, or "streamed" to your working directory. For this tutorial, we will set the request mode to asynchronous, which will allow concurrent requests to be queued and processed without the need for a continuous connection.
#
# **Use the streaming `request_mode` with caution: While it can be beneficial to stream outputs directly to your local directory, note that timeout errors can result depending on the size of the request, and your request will not be queued in the system if NSIDC is experiencing high request volume. For best performance, NSIDC recommends setting `page_size=1` to download individual outputs, which will eliminate extra time needed to zip outputs and will ensure faster processing times per request. An example streaming request loop is available at the bottom of the tutorial below.**
#
# Recall that we queried the total number and volume of granules prior to applying customization services. `page_size` and `page_num` can be used to adjust the number of granules per request up to a limit of 2000 granules for asynchronous, and 100 granules for synchronous (streaming). For now, let's select 10 granules to be processed in each zipped request. For ATL06, the granule size can exceed 100 MB so we want to choose a granule count that provides us with a reasonable zipped download size.
#
# If no keyword inputs are entered into the build function for these parameters, default values will be used. We must also specify that we would like to build the required configuration parameters for downloading (versus those needed for a 'search').

# %%
region_a.build_reqconfig_params('download', page_size=9)

# %%
region_a.reqparams
# Out:
# {'page_size': 9, 'page_num': 1, 'request_mode': 'async', 'include_meta': 'Y'}

# %% [markdown]
# #### Place the order
# Then, we can send the order to NSIDC by providing our active session to the order_granules function. Information about the granules ordered and their status will be printed automatically as well as emailed to the address provided. Additional information on the order, including request URLs, can be viewed by setting the optional keyword input 'verbose' to True.

# %%
region_a.order_granules(session)
#region_a.order_granules(session, verbose=True)
# Out:
# Order:  1
# Request HTTP response:  201
# Order request URL:  https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=002&temporal=2019-02-22T00%3A00%3A00Z%2C2019-02-28T23%3A59%3A59Z&bounding_box=-64%2C66%2C-55%2C72&page_size=9&page_num=1&email=jessica.scheick%40maine.edu&token=E175B383-E4B9-57E2-7F53-C901D287A528&request_mode=async&agent=NO&include_meta=Y
# Order request response XML content:  b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<eesi:agentResponse xsi:schemaLocation="http://eosdis.nasa.gov/esi/rsp/e https://newsroom.gsfc.nasa.gov/esi/8.1/schemas/ESIAgentResponseExternal.xsd" xmlns="" xmlns:iesi="http://eosdis.nasa.gov/esi/rsp/i" xmlns:ssw="http://newsroom.gsfc.nasa.gov/esi/rsp/ssw" xmlns:eesi="http://eosdis.nasa.gov/esi/rsp/e" xmlns:esi="http://eosdis.nasa.gov/esi/rsp" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n    <order>\n        <orderId>5000000416602</orderId>\n        <Instructions>You may receive an email about your order if you specified an EMAIL address. &lt;br/&gt;&lt;br/&gt;The instructions used to process this order are:  Processing tool=NO. Include metadata and processing history=Y. Granule id(s)=SC:ATL06.002:166252035,SC:ATL06.002:166228209,SC:ATL06.002:166290953,SC:ATL06.002:166227755,SC:ATL06.002:166266202,SC:ATL06.002:166232766,SC:ATL06.002:166242951. Email address=jessica.scheick@maine.edu.</Instructions>\n    </order>\n    <contactInformation>\n        <contactName>NSIDC User Services</contactName>\n        <contactEmail>nsidc@nsidc.org</contactEmail>\n    </contactInformation>\n    <processInfo>\n        <processDuration>PT0.102S</processDuration>\n        <subagentId>NO</subagentId>\n    </processInfo>\n    <requestStatus>\n        <status>processing</status>\n        <numberProcessed>0</numberProcessed>\n        <totalNumber>7</totalNumber>\n    </requestStatus>\n</eesi:agentResponse>\n'
# <Element 'orderId' at 0x117ae57c8>
# <Element 'Instructions' at 0x117ae5818>
# order ID:  5000000416602
# status URL:  https://n5eil02u.ecs.nsidc.org/egi/request/5000000416602
# HTTP response from order response URL:  201
# Data request  1  is submitting...
# Initial request status is  processing
# Status is not complete. Trying again.
# Retry request status is:  complete

# %%
#view a short list of order IDs
region_a.orderIDs
# Out:
# ['5000000416602']

# %% [markdown]
# #### Download the order
# Finally, we can download our order to a specified directory (which needs to have a full path but doesn't have to point to an existing directory) and the download status will be printed as the program runs. Additional information is again available by using the optional boolean keyword 'verbose'.

# %%
path = './downloads'
region_a.download_granules(session, path)
# Out:
# Order:  1
# Request HTTP response:  201
# Order request URL:  https://n5eil02u.ecs.nsidc.org/egi/request?short_name=ATL06&version=002&temporal=2019-02-22T00%3A00%3A00Z%2C2019-02-28T23%3A59%3A59Z&bounding_box=-64%2C66%2C-55%2C72&email=jessica.scheick%40maine.edu&token=464C6E30-135C-0274-5E50-8DA341E5D482&page_size=10&page_num=1&request_mode=async&agent=NO&include_meta=Y
# Order request response XML content:  b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\n<eesi:agentResponse xsi:schemaLocation="http://eosdis.nasa.gov/esi/rsp/e https://newsroom.gsfc.nasa.gov/esi/8.1/schemas/ESIAgentResponseExternal.xsd" xmlns="" xmlns:iesi="http://eosdis.nasa.gov/esi/rsp/i" xmlns:ssw="http://newsroom.gsfc.nasa.gov/esi/rsp/ssw" xmlns:eesi="http://eosdis.nasa.gov/esi/rsp/e" xmlns:esi="http://eosdis.nasa.gov/esi/rsp" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">\n    <order>\n        <orderId>5000000415433</orderId>\n        <Instructions>You may receive an email about your order if you specified an EMAIL address. &lt;br/&gt;&lt;br/&gt;The instructions used to process this order are:  Processing tool=NO. Include metadata and processing history=Y. Granule id(s)=SC:ATL06.002:166252035,SC:ATL06.002:166228209,SC:ATL06.002:166290953,SC:ATL06.002:166227755,SC:ATL06.002:166266202,SC:ATL06.002:166232766,SC:ATL06.002:166242951. Email address=jessica.scheick@maine.edu.</Instructions>\n    </order>\n    <contactInformation>\n        <contactName>NSIDC User Services</contactName>\n        <contactEmail>nsidc@nsidc.org</contactEmail>\n    </contactInformation>\n    <processInfo>\n        <processDuration>PT0.103S</processDuration>\n        <subagentId>NO</subagentId>\n    </processInfo>\n    <requestStatus>\n        <status>processing</status>\n        <numberProcessed>0</numberProcessed>\n        <totalNumber>7</totalNumber>\n    </requestStatus>\n</eesi:agentResponse>\n'
# <Element 'orderId' at 0x11747aea8>
# <Element 'Instructions' at 0x11747a908>
# order ID:  5000000415433
# status URL:  https://n5eil02u.ecs.nsidc.org/egi/request/5000000415433
# HTTP response from order response URL:  201
# Data request  1  is submitting...
# Initial request status is  processing
# Status is not complete. Trying again.
# Retry request status is:  complete
# Zip download URL:  https://n5eil02u.ecs.nsidc.org/esir/5000000415433.zip
# Beginning download of zipped output...
# Data request 5000000415433 of  1  order(s) is complete.

# %% [markdown]
# #### Clean up the download folder by removing individual order folders:

# %%
#Clean up Outputs folder by removing individual granule folders 

for root, dirs, files in os.walk(path, topdown=False):
    for file in files:
        try:
            shutil.move(os.path.join(root, file), path)
        except OSError:
            pass
        
for root, dirs, files in os.walk(path):
    for name in dirs:
        os.rmdir(os.path.join(root, name))

# %% [markdown]
# ## Elements to develop further/implement (and then include in the example, as in Amy's tutorial)
# - cleaning up of download folder (default vs above code block as part of example)
# - customization: subsetting and reformatting (check for options and include with order)
# - more information/details on the above steps for a novice user
