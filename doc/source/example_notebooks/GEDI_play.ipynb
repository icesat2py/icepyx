# %% [markdown]
# # Using icepyx for GEDI
#
# This notebook aims to explore the use of icepyx, specifically the variables module, for working with GEDI data.
#
# The motivation was Mahsa's 20 Feb 2024 earthaccess presentation of a GEDI notebook, including noting some variable management challenges.
# This notebook demonstrates that the icepyx variables module could be useful for managing GEDI variables as well.
#
# Detailed tutorial for using icepyx's Variables module: https://icepyx.readthedocs.io/en/latest/example_notebooks/IS2_data_variables.html
#
# The only changes made to the underlying icepyx code were to comment out the portion of `Variables.__init__` (lines 83-107 on the dev branch) that extracts the dataset product and version and then add a new `self._path=path` in place of the commented code. The version and product come from the ICESat-2 metadata and are then validated against a hard-coded list of ICESat-2 data products, so even if a valid version and product were extracted from GEDI the checks would obviously fail.
#
# The notebook also includes a few notes on where I (as a user) wanted better earthaccess docs for contributing to the ongoing docs improvements and restructure (https://github.com/nsidc/earthaccess/tree/update-documentation). My hope is that this notebook can seed a basic tutorial notebook that shows how to use earthaccess to search for a dataset when all one knows is the sensor name.

# %%
# %load_ext autoreload
import icepyx as ipx
# %autoreload 2
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b26c60bf-0898-4981-8bae-35a421975fd3" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7be9175d-f79d-4df7-8f50-7399df5ca6c9":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"1ac57a5df8eb47aea0aedb87fb61901b","client_comm_id":"bc30b8677e4e4defb1e59911f69b6426"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"7be9175d-f79d-4df7-8f50-7399df5ca6c9","roots":{"p1002":"b26c60bf-0898-4981-8bae-35a421975fd3"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
import earthaccess

# %%
auth = earthaccess.login()
# Out:
# Enter your Earthdata Login username:  icepyx_devteam
# Enter your Earthdata password:  ········

# %% [markdown]
# ### earthaccess Notes/challenges:
# - navigating the output from search_datasets (`.summary` only accepts a single dict from the list output by `.search_datasets`, and `keyword="GEDI"` returns 22 datasets)
# - terms that are a bit jargony: concept_ID vs shortname, collection vs dataset
# - docs need examples for running the various functions, and clarity on which things are classes, methods, kwargs, etc. For instance, on https://earthaccess.readthedocs.io/en/latest/user-reference/collections/collections-query/, in the right hand TOC in a single list are the CollectionQuery class, the keyword kwarg (which cannot be passed to CollectionQuery), and the paramaters method (for the DataCollections class object).

# %%
# How/why would I use the collection_query class (as a user)? Or is it the underlying object type I don't call directly?
coll = earthaccess.collection_query()
coll

# %% [markdown]
# ## Identifying a dataset
#
# You can search for individual data products using the `keyword="string"` argument.
# This is helpful if you know the name of the sensor or satellite but not the specific product name syntax.
#
# `earthaccess.search_datasets()` will return a list of datasets, where each entry is a dictionary containing CMR metadata...

# %%
earthaccess.search_datasets(keyword="GEDI")[0].summary()
# Out:
# Datasets found: 22
# {'short-name': 'GEDI_L4A_AGB_Density_V2_1_2056',
#  'concept-id': 'C2237824918-ORNL_CLOUD',
#  'version': '2.1',
#  'file-type': "[{'FormatType': 'Native', 'Fees': '0', 'Format': 'HDF5'}]",
#  'get-data': ['https://daac.ornl.gov/daacdata/gedi/GEDI_L4A_AGB_Density_V2_1/'],
#  'cloud-info': {'Region': 'us-west-2',
#   'S3BucketAndObjectPrefixNames': ['s3://ornl-cumulus-prod-protected/gedi/GEDI_L4A_AGB_Density_V2_1/'],
#   'S3CredentialsAPIEndpoint': 'https://data.ornldaac.earthdata.nasa.gov/s3credentials',
#   'S3CredentialsAPIDocumentationURL': 'https://data.ornldaac.earthdata.nasa.gov/s3credentialsREADME'}}

# %%
# from https://github.com/nasa/GEDI-Data-Resources/blob/main/python/tutorials/GEDI_Finder_Tutorial_Python.ipynb
product = 'GEDI_L4A_AGB_Density_V2_1_2056'           # Options for concept ID include 'GEDI01_B.002', 'GEDI02_A.002', 'GEDI02_B.002'
bbox = (-73.65,-12.64,-47.81,9.7)  # bounding box coordinates in LL Longitude, LL Latitude, UR Longitude, UR Latitude format

# %%
results = earthaccess.search_data(
    short_name=product,
    temporal=('2023-03-01', '2023-03-02'),
    bounding_box=bbox
)
# Out:
# Granules found: 5

# %%
results[0]
# Out:
# Collection: {'ShortName': 'GEDI_L4A_AGB_Density_V2_1_2056', 'Version': '2.1'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -86.2728119, 'Latitude': -33.864006}, {'Longitude': -83.1607742, 'Latitude': -31.25424}, {'Longitude': -80.2245865, 'Latitude': -28.5366497}, {'Longitude': -77.4485779, 'Latitude': -25.7463112}, {'Longitude': -74.8107452, 'Latitude': -22.8939514}, {'Longitude': -72.2914886, 'Latitude': -19.9901447}, {'Longitude': -69.8707733, 'Latitude': -17.0420227}, {'Longitude': -67.5331726, 'Latitude': -14.0606089}, {'Longitude': -65.2610474, 'Latitude': -11.0497828}, {'Longitude': -63.0390778, 'Latitude': -8.0173254}, {'Longitude': -60.8528481, 'Latitude': -4.9693408}, {'Longitude': -58.6880455, 'Latitude': -1.910857}, {'Longitude': -57.5156212, 'Latitude': -0.247125}, {'Longitude': -57.5755997, 'Latitude': -0.185566}, {'Longitude': -58.7477264, 'Latitude': -1.849561}, {'Longitude': -60.9121437, 'Latitude': -4.9068909}, {'Longitude': -63.0990906, 'Latitude': -7.9549661}, {'Longitude': -65.3213272, 'Latitude': -10.9870481}, {'Longitude': -67.5935593, 'Latitude': -13.9971657}, {'Longitude': -69.930954, 'Latitude': -16.9781132}, {'Longitude': -72.3515854, 'Latitude': -19.924572}, {'Longitude': -74.87117, 'Latitude': -22.8275948}, {'Longitude': -77.5088577, 'Latitude': -25.6786289}, {'Longitude': -80.2844772, 'Latitude': -28.4675236}, {'Longitude': -83.2201385, 'Latitude': -31.1835899}, {'Longitude': -86.3106308, 'Latitude': -33.8318329}, {'Longitude': -86.2728119, 'Latitude': -33.864006}]}}]}}}
# Temporal coverage: {'RangeDateTime': {'BeginningDateTime': '2023-03-01T02:38:42.000Z', 'EndingDateTime': '2023-03-01T02:50:14.000Z'}}
# Size(MB): 155.207993
# Data: ['https://data.ornldaac.earthdata.nasa.gov/protected/gedi/GEDI_L4A_AGB_Density_V2_1/data/GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5', 'https://data.ornldaac.earthdata.nasa.gov/public/gedi/GEDI_L4A_AGB_Density_V2_1/data/GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5.sha256']

# %%
downloaded_files = earthaccess.download(
    results[0],
    local_path='./GEDI/',
)
# Out:
#  Getting 1 granules, approx download size: 0.15 GB
# QUEUEING TASKS | :   0%|          | 0/2 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/2 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# %ls ./GEDI/
# Out:
# GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5
# GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5.sha256

# %%
vars = ipx.Variables(path="./GEDI/GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5")

# %%
vars._product="GEDI" #to trick icepyx because we commented out the setting of _product from the metadata

# %%
vars.path
# Out:
# './GEDI/GEDI04_A_2023060022721_O23871_01_T01222_02_003_01_V002.h5'

# %%
vars.avail()
# Out:
# ['ANCILLARY/model_data',
#  'ANCILLARY/pft_lut',
#  'ANCILLARY/region_lut',
#  'BEAM0000/agbd',
#  'BEAM0000/agbd_pi_lower',
#  'BEAM0000/agbd_pi_upper',
#  'BEAM0000/agbd_prediction/agbd_a1',
#  'BEAM0000/agbd_prediction/agbd_a10',
#  'BEAM0000/agbd_prediction/agbd_a2',
#  'BEAM0000/agbd_prediction/agbd_a3',
#  'BEAM0000/agbd_prediction/agbd_a4',
#  'BEAM0000/agbd_prediction/agbd_a5',
#  'BEAM0000/agbd_prediction/agbd_a6',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0000/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0000/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0000/agbd_prediction/agbd_se_a1',
#  'BEAM0000/agbd_prediction/agbd_se_a10',
#  'BEAM0000/agbd_prediction/agbd_se_a2',
#  'BEAM0000/agbd_prediction/agbd_se_a3',
#  'BEAM0000/agbd_prediction/agbd_se_a4',
#  'BEAM0000/agbd_prediction/agbd_se_a5',
#  'BEAM0000/agbd_prediction/agbd_se_a6',
#  'BEAM0000/agbd_prediction/agbd_t_a1',
#  'BEAM0000/agbd_prediction/agbd_t_a10',
#  'BEAM0000/agbd_prediction/agbd_t_a2',
#  'BEAM0000/agbd_prediction/agbd_t_a3',
#  'BEAM0000/agbd_prediction/agbd_t_a4',
#  'BEAM0000/agbd_prediction/agbd_t_a5',
#  'BEAM0000/agbd_prediction/agbd_t_a6',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0000/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0000/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0000/agbd_prediction/agbd_t_se_a1',
#  'BEAM0000/agbd_prediction/agbd_t_se_a10',
#  'BEAM0000/agbd_prediction/agbd_t_se_a2',
#  'BEAM0000/agbd_prediction/agbd_t_se_a3',
#  'BEAM0000/agbd_prediction/agbd_t_se_a4',
#  'BEAM0000/agbd_prediction/agbd_t_se_a5',
#  'BEAM0000/agbd_prediction/agbd_t_se_a6',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0000/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0000/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0000/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0000/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0000/agbd_prediction/response_limit_flag_a1',
#  'BEAM0000/agbd_prediction/response_limit_flag_a10',
#  'BEAM0000/agbd_prediction/response_limit_flag_a2',
#  'BEAM0000/agbd_prediction/response_limit_flag_a3',
#  'BEAM0000/agbd_prediction/response_limit_flag_a4',
#  'BEAM0000/agbd_prediction/response_limit_flag_a5',
#  'BEAM0000/agbd_prediction/response_limit_flag_a6',
#  'BEAM0000/agbd_prediction/selected_mode_a1',
#  'BEAM0000/agbd_prediction/selected_mode_a10',
#  'BEAM0000/agbd_prediction/selected_mode_a2',
#  'BEAM0000/agbd_prediction/selected_mode_a3',
#  'BEAM0000/agbd_prediction/selected_mode_a4',
#  'BEAM0000/agbd_prediction/selected_mode_a5',
#  'BEAM0000/agbd_prediction/selected_mode_a6',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a1',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a10',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a2',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a3',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a4',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a5',
#  'BEAM0000/agbd_prediction/selected_mode_flag_a6',
#  'BEAM0000/agbd_prediction/shot_number',
#  'BEAM0000/agbd_prediction/xvar_a1',
#  'BEAM0000/agbd_prediction/xvar_a10',
#  'BEAM0000/agbd_prediction/xvar_a2',
#  'BEAM0000/agbd_prediction/xvar_a3',
#  'BEAM0000/agbd_prediction/xvar_a4',
#  'BEAM0000/agbd_prediction/xvar_a5',
#  'BEAM0000/agbd_prediction/xvar_a6',
#  'BEAM0000/agbd_se',
#  'BEAM0000/agbd_t',
#  'BEAM0000/agbd_t_se',
#  'BEAM0000/algorithm_run_flag',
#  'BEAM0000/beam',
#  'BEAM0000/channel',
#  'BEAM0000/degrade_flag',
#  'BEAM0000/delta_time',
#  'BEAM0000/elev_lowestmode',
#  'BEAM0000/geolocation/elev_lowestmode_a1',
#  'BEAM0000/geolocation/elev_lowestmode_a10',
#  'BEAM0000/geolocation/elev_lowestmode_a2',
#  'BEAM0000/geolocation/elev_lowestmode_a3',
#  'BEAM0000/geolocation/elev_lowestmode_a4',
#  'BEAM0000/geolocation/elev_lowestmode_a5',
#  'BEAM0000/geolocation/elev_lowestmode_a6',
#  'BEAM0000/geolocation/lat_lowestmode_a1',
#  'BEAM0000/geolocation/lat_lowestmode_a10',
#  'BEAM0000/geolocation/lat_lowestmode_a2',
#  'BEAM0000/geolocation/lat_lowestmode_a3',
#  'BEAM0000/geolocation/lat_lowestmode_a4',
#  'BEAM0000/geolocation/lat_lowestmode_a5',
#  'BEAM0000/geolocation/lat_lowestmode_a6',
#  'BEAM0000/geolocation/lon_lowestmode_a1',
#  'BEAM0000/geolocation/lon_lowestmode_a10',
#  'BEAM0000/geolocation/lon_lowestmode_a2',
#  'BEAM0000/geolocation/lon_lowestmode_a3',
#  'BEAM0000/geolocation/lon_lowestmode_a4',
#  'BEAM0000/geolocation/lon_lowestmode_a5',
#  'BEAM0000/geolocation/lon_lowestmode_a6',
#  'BEAM0000/geolocation/sensitivity_a1',
#  'BEAM0000/geolocation/sensitivity_a10',
#  'BEAM0000/geolocation/sensitivity_a2',
#  'BEAM0000/geolocation/sensitivity_a3',
#  'BEAM0000/geolocation/sensitivity_a4',
#  'BEAM0000/geolocation/sensitivity_a6',
#  'BEAM0000/geolocation/stale_return_flag',
#  'BEAM0000/l2_quality_flag',
#  'BEAM0000/l4_quality_flag',
#  'BEAM0000/land_cover_data/landsat_treecover',
#  'BEAM0000/land_cover_data/landsat_water_persistence',
#  'BEAM0000/land_cover_data/leaf_off_doy',
#  'BEAM0000/land_cover_data/leaf_off_flag',
#  'BEAM0000/land_cover_data/leaf_on_cycle',
#  'BEAM0000/land_cover_data/leaf_on_doy',
#  'BEAM0000/land_cover_data/pft_class',
#  'BEAM0000/land_cover_data/region_class',
#  'BEAM0000/land_cover_data/urban_focal_window_size',
#  'BEAM0000/land_cover_data/urban_proportion',
#  'BEAM0000/lat_lowestmode',
#  'BEAM0000/lon_lowestmode',
#  'BEAM0000/master_frac',
#  'BEAM0000/master_int',
#  'BEAM0000/predict_stratum',
#  'BEAM0000/predictor_limit_flag',
#  'BEAM0000/response_limit_flag',
#  'BEAM0000/selected_algorithm',
#  'BEAM0000/selected_mode',
#  'BEAM0000/selected_mode_flag',
#  'BEAM0000/sensitivity',
#  'BEAM0000/solar_elevation',
#  'BEAM0000/surface_flag',
#  'BEAM0000/xvar',
#  'BEAM0001/agbd',
#  'BEAM0001/agbd_pi_lower',
#  'BEAM0001/agbd_pi_upper',
#  'BEAM0001/agbd_prediction/agbd_a1',
#  'BEAM0001/agbd_prediction/agbd_a10',
#  'BEAM0001/agbd_prediction/agbd_a2',
#  'BEAM0001/agbd_prediction/agbd_a3',
#  'BEAM0001/agbd_prediction/agbd_a4',
#  'BEAM0001/agbd_prediction/agbd_a5',
#  'BEAM0001/agbd_prediction/agbd_a6',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0001/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0001/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0001/agbd_prediction/agbd_se_a1',
#  'BEAM0001/agbd_prediction/agbd_se_a10',
#  'BEAM0001/agbd_prediction/agbd_se_a2',
#  'BEAM0001/agbd_prediction/agbd_se_a3',
#  'BEAM0001/agbd_prediction/agbd_se_a4',
#  'BEAM0001/agbd_prediction/agbd_se_a5',
#  'BEAM0001/agbd_prediction/agbd_se_a6',
#  'BEAM0001/agbd_prediction/agbd_t_a1',
#  'BEAM0001/agbd_prediction/agbd_t_a10',
#  'BEAM0001/agbd_prediction/agbd_t_a2',
#  'BEAM0001/agbd_prediction/agbd_t_a3',
#  'BEAM0001/agbd_prediction/agbd_t_a4',
#  'BEAM0001/agbd_prediction/agbd_t_a5',
#  'BEAM0001/agbd_prediction/agbd_t_a6',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0001/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0001/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0001/agbd_prediction/agbd_t_se_a1',
#  'BEAM0001/agbd_prediction/agbd_t_se_a10',
#  'BEAM0001/agbd_prediction/agbd_t_se_a2',
#  'BEAM0001/agbd_prediction/agbd_t_se_a3',
#  'BEAM0001/agbd_prediction/agbd_t_se_a4',
#  'BEAM0001/agbd_prediction/agbd_t_se_a5',
#  'BEAM0001/agbd_prediction/agbd_t_se_a6',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0001/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0001/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0001/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0001/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0001/agbd_prediction/response_limit_flag_a1',
#  'BEAM0001/agbd_prediction/response_limit_flag_a10',
#  'BEAM0001/agbd_prediction/response_limit_flag_a2',
#  'BEAM0001/agbd_prediction/response_limit_flag_a3',
#  'BEAM0001/agbd_prediction/response_limit_flag_a4',
#  'BEAM0001/agbd_prediction/response_limit_flag_a5',
#  'BEAM0001/agbd_prediction/response_limit_flag_a6',
#  'BEAM0001/agbd_prediction/selected_mode_a1',
#  'BEAM0001/agbd_prediction/selected_mode_a10',
#  'BEAM0001/agbd_prediction/selected_mode_a2',
#  'BEAM0001/agbd_prediction/selected_mode_a3',
#  'BEAM0001/agbd_prediction/selected_mode_a4',
#  'BEAM0001/agbd_prediction/selected_mode_a5',
#  'BEAM0001/agbd_prediction/selected_mode_a6',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a1',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a10',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a2',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a3',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a4',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a5',
#  'BEAM0001/agbd_prediction/selected_mode_flag_a6',
#  'BEAM0001/agbd_prediction/shot_number',
#  'BEAM0001/agbd_prediction/xvar_a1',
#  'BEAM0001/agbd_prediction/xvar_a10',
#  'BEAM0001/agbd_prediction/xvar_a2',
#  'BEAM0001/agbd_prediction/xvar_a3',
#  'BEAM0001/agbd_prediction/xvar_a4',
#  'BEAM0001/agbd_prediction/xvar_a5',
#  'BEAM0001/agbd_prediction/xvar_a6',
#  'BEAM0001/agbd_se',
#  'BEAM0001/agbd_t',
#  'BEAM0001/agbd_t_se',
#  'BEAM0001/algorithm_run_flag',
#  'BEAM0001/beam',
#  'BEAM0001/channel',
#  'BEAM0001/degrade_flag',
#  'BEAM0001/delta_time',
#  'BEAM0001/elev_lowestmode',
#  'BEAM0001/geolocation/elev_lowestmode_a1',
#  'BEAM0001/geolocation/elev_lowestmode_a10',
#  'BEAM0001/geolocation/elev_lowestmode_a2',
#  'BEAM0001/geolocation/elev_lowestmode_a3',
#  'BEAM0001/geolocation/elev_lowestmode_a4',
#  'BEAM0001/geolocation/elev_lowestmode_a5',
#  'BEAM0001/geolocation/elev_lowestmode_a6',
#  'BEAM0001/geolocation/lat_lowestmode_a1',
#  'BEAM0001/geolocation/lat_lowestmode_a10',
#  'BEAM0001/geolocation/lat_lowestmode_a2',
#  'BEAM0001/geolocation/lat_lowestmode_a3',
#  'BEAM0001/geolocation/lat_lowestmode_a4',
#  'BEAM0001/geolocation/lat_lowestmode_a5',
#  'BEAM0001/geolocation/lat_lowestmode_a6',
#  'BEAM0001/geolocation/lon_lowestmode_a1',
#  'BEAM0001/geolocation/lon_lowestmode_a10',
#  'BEAM0001/geolocation/lon_lowestmode_a2',
#  'BEAM0001/geolocation/lon_lowestmode_a3',
#  'BEAM0001/geolocation/lon_lowestmode_a4',
#  'BEAM0001/geolocation/lon_lowestmode_a5',
#  'BEAM0001/geolocation/lon_lowestmode_a6',
#  'BEAM0001/geolocation/sensitivity_a1',
#  'BEAM0001/geolocation/sensitivity_a10',
#  'BEAM0001/geolocation/sensitivity_a2',
#  'BEAM0001/geolocation/sensitivity_a3',
#  'BEAM0001/geolocation/sensitivity_a4',
#  'BEAM0001/geolocation/sensitivity_a6',
#  'BEAM0001/geolocation/stale_return_flag',
#  'BEAM0001/l2_quality_flag',
#  'BEAM0001/l4_quality_flag',
#  'BEAM0001/land_cover_data/landsat_treecover',
#  'BEAM0001/land_cover_data/landsat_water_persistence',
#  'BEAM0001/land_cover_data/leaf_off_doy',
#  'BEAM0001/land_cover_data/leaf_off_flag',
#  'BEAM0001/land_cover_data/leaf_on_cycle',
#  'BEAM0001/land_cover_data/leaf_on_doy',
#  'BEAM0001/land_cover_data/pft_class',
#  'BEAM0001/land_cover_data/region_class',
#  'BEAM0001/land_cover_data/urban_focal_window_size',
#  'BEAM0001/land_cover_data/urban_proportion',
#  'BEAM0001/lat_lowestmode',
#  'BEAM0001/lon_lowestmode',
#  'BEAM0001/master_frac',
#  'BEAM0001/master_int',
#  'BEAM0001/predict_stratum',
#  'BEAM0001/predictor_limit_flag',
#  'BEAM0001/response_limit_flag',
#  'BEAM0001/selected_algorithm',
#  'BEAM0001/selected_mode',
#  'BEAM0001/selected_mode_flag',
#  'BEAM0001/sensitivity',
#  'BEAM0001/solar_elevation',
#  'BEAM0001/surface_flag',
#  'BEAM0001/xvar',
#  'BEAM0010/agbd',
#  'BEAM0010/agbd_pi_lower',
#  'BEAM0010/agbd_pi_upper',
#  'BEAM0010/agbd_prediction/agbd_a1',
#  'BEAM0010/agbd_prediction/agbd_a10',
#  'BEAM0010/agbd_prediction/agbd_a2',
#  'BEAM0010/agbd_prediction/agbd_a3',
#  'BEAM0010/agbd_prediction/agbd_a4',
#  'BEAM0010/agbd_prediction/agbd_a5',
#  'BEAM0010/agbd_prediction/agbd_a6',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0010/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0010/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0010/agbd_prediction/agbd_se_a1',
#  'BEAM0010/agbd_prediction/agbd_se_a10',
#  'BEAM0010/agbd_prediction/agbd_se_a2',
#  'BEAM0010/agbd_prediction/agbd_se_a3',
#  'BEAM0010/agbd_prediction/agbd_se_a4',
#  'BEAM0010/agbd_prediction/agbd_se_a5',
#  'BEAM0010/agbd_prediction/agbd_se_a6',
#  'BEAM0010/agbd_prediction/agbd_t_a1',
#  'BEAM0010/agbd_prediction/agbd_t_a10',
#  'BEAM0010/agbd_prediction/agbd_t_a2',
#  'BEAM0010/agbd_prediction/agbd_t_a3',
#  'BEAM0010/agbd_prediction/agbd_t_a4',
#  'BEAM0010/agbd_prediction/agbd_t_a5',
#  'BEAM0010/agbd_prediction/agbd_t_a6',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0010/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0010/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0010/agbd_prediction/agbd_t_se_a1',
#  'BEAM0010/agbd_prediction/agbd_t_se_a10',
#  'BEAM0010/agbd_prediction/agbd_t_se_a2',
#  'BEAM0010/agbd_prediction/agbd_t_se_a3',
#  'BEAM0010/agbd_prediction/agbd_t_se_a4',
#  'BEAM0010/agbd_prediction/agbd_t_se_a5',
#  'BEAM0010/agbd_prediction/agbd_t_se_a6',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0010/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0010/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0010/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0010/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0010/agbd_prediction/response_limit_flag_a1',
#  'BEAM0010/agbd_prediction/response_limit_flag_a10',
#  'BEAM0010/agbd_prediction/response_limit_flag_a2',
#  'BEAM0010/agbd_prediction/response_limit_flag_a3',
#  'BEAM0010/agbd_prediction/response_limit_flag_a4',
#  'BEAM0010/agbd_prediction/response_limit_flag_a5',
#  'BEAM0010/agbd_prediction/response_limit_flag_a6',
#  'BEAM0010/agbd_prediction/selected_mode_a1',
#  'BEAM0010/agbd_prediction/selected_mode_a10',
#  'BEAM0010/agbd_prediction/selected_mode_a2',
#  'BEAM0010/agbd_prediction/selected_mode_a3',
#  'BEAM0010/agbd_prediction/selected_mode_a4',
#  'BEAM0010/agbd_prediction/selected_mode_a5',
#  'BEAM0010/agbd_prediction/selected_mode_a6',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a1',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a10',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a2',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a3',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a4',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a5',
#  'BEAM0010/agbd_prediction/selected_mode_flag_a6',
#  'BEAM0010/agbd_prediction/shot_number',
#  'BEAM0010/agbd_prediction/xvar_a1',
#  'BEAM0010/agbd_prediction/xvar_a10',
#  'BEAM0010/agbd_prediction/xvar_a2',
#  'BEAM0010/agbd_prediction/xvar_a3',
#  'BEAM0010/agbd_prediction/xvar_a4',
#  'BEAM0010/agbd_prediction/xvar_a5',
#  'BEAM0010/agbd_prediction/xvar_a6',
#  'BEAM0010/agbd_se',
#  'BEAM0010/agbd_t',
#  'BEAM0010/agbd_t_se',
#  'BEAM0010/algorithm_run_flag',
#  'BEAM0010/beam',
#  'BEAM0010/channel',
#  'BEAM0010/degrade_flag',
#  'BEAM0010/delta_time',
#  'BEAM0010/elev_lowestmode',
#  'BEAM0010/geolocation/elev_lowestmode_a1',
#  'BEAM0010/geolocation/elev_lowestmode_a10',
#  'BEAM0010/geolocation/elev_lowestmode_a2',
#  'BEAM0010/geolocation/elev_lowestmode_a3',
#  'BEAM0010/geolocation/elev_lowestmode_a4',
#  'BEAM0010/geolocation/elev_lowestmode_a5',
#  'BEAM0010/geolocation/elev_lowestmode_a6',
#  'BEAM0010/geolocation/lat_lowestmode_a1',
#  'BEAM0010/geolocation/lat_lowestmode_a10',
#  'BEAM0010/geolocation/lat_lowestmode_a2',
#  'BEAM0010/geolocation/lat_lowestmode_a3',
#  'BEAM0010/geolocation/lat_lowestmode_a4',
#  'BEAM0010/geolocation/lat_lowestmode_a5',
#  'BEAM0010/geolocation/lat_lowestmode_a6',
#  'BEAM0010/geolocation/lon_lowestmode_a1',
#  'BEAM0010/geolocation/lon_lowestmode_a10',
#  'BEAM0010/geolocation/lon_lowestmode_a2',
#  'BEAM0010/geolocation/lon_lowestmode_a3',
#  'BEAM0010/geolocation/lon_lowestmode_a4',
#  'BEAM0010/geolocation/lon_lowestmode_a5',
#  'BEAM0010/geolocation/lon_lowestmode_a6',
#  'BEAM0010/geolocation/sensitivity_a1',
#  'BEAM0010/geolocation/sensitivity_a10',
#  'BEAM0010/geolocation/sensitivity_a2',
#  'BEAM0010/geolocation/sensitivity_a3',
#  'BEAM0010/geolocation/sensitivity_a4',
#  'BEAM0010/geolocation/sensitivity_a6',
#  'BEAM0010/geolocation/stale_return_flag',
#  'BEAM0010/l2_quality_flag',
#  'BEAM0010/l4_quality_flag',
#  'BEAM0010/land_cover_data/landsat_treecover',
#  'BEAM0010/land_cover_data/landsat_water_persistence',
#  'BEAM0010/land_cover_data/leaf_off_doy',
#  'BEAM0010/land_cover_data/leaf_off_flag',
#  'BEAM0010/land_cover_data/leaf_on_cycle',
#  'BEAM0010/land_cover_data/leaf_on_doy',
#  'BEAM0010/land_cover_data/pft_class',
#  'BEAM0010/land_cover_data/region_class',
#  'BEAM0010/land_cover_data/urban_focal_window_size',
#  'BEAM0010/land_cover_data/urban_proportion',
#  'BEAM0010/lat_lowestmode',
#  'BEAM0010/lon_lowestmode',
#  'BEAM0010/master_frac',
#  'BEAM0010/master_int',
#  'BEAM0010/predict_stratum',
#  'BEAM0010/predictor_limit_flag',
#  'BEAM0010/response_limit_flag',
#  'BEAM0010/selected_algorithm',
#  'BEAM0010/selected_mode',
#  'BEAM0010/selected_mode_flag',
#  'BEAM0010/sensitivity',
#  'BEAM0010/solar_elevation',
#  'BEAM0010/surface_flag',
#  'BEAM0010/xvar',
#  'BEAM0011/agbd',
#  'BEAM0011/agbd_pi_lower',
#  'BEAM0011/agbd_pi_upper',
#  'BEAM0011/agbd_prediction/agbd_a1',
#  'BEAM0011/agbd_prediction/agbd_a10',
#  'BEAM0011/agbd_prediction/agbd_a2',
#  'BEAM0011/agbd_prediction/agbd_a3',
#  'BEAM0011/agbd_prediction/agbd_a4',
#  'BEAM0011/agbd_prediction/agbd_a5',
#  'BEAM0011/agbd_prediction/agbd_a6',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0011/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0011/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0011/agbd_prediction/agbd_se_a1',
#  'BEAM0011/agbd_prediction/agbd_se_a10',
#  'BEAM0011/agbd_prediction/agbd_se_a2',
#  'BEAM0011/agbd_prediction/agbd_se_a3',
#  'BEAM0011/agbd_prediction/agbd_se_a4',
#  'BEAM0011/agbd_prediction/agbd_se_a5',
#  'BEAM0011/agbd_prediction/agbd_se_a6',
#  'BEAM0011/agbd_prediction/agbd_t_a1',
#  'BEAM0011/agbd_prediction/agbd_t_a10',
#  'BEAM0011/agbd_prediction/agbd_t_a2',
#  'BEAM0011/agbd_prediction/agbd_t_a3',
#  'BEAM0011/agbd_prediction/agbd_t_a4',
#  'BEAM0011/agbd_prediction/agbd_t_a5',
#  'BEAM0011/agbd_prediction/agbd_t_a6',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0011/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0011/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0011/agbd_prediction/agbd_t_se_a1',
#  'BEAM0011/agbd_prediction/agbd_t_se_a10',
#  'BEAM0011/agbd_prediction/agbd_t_se_a2',
#  'BEAM0011/agbd_prediction/agbd_t_se_a3',
#  'BEAM0011/agbd_prediction/agbd_t_se_a4',
#  'BEAM0011/agbd_prediction/agbd_t_se_a5',
#  'BEAM0011/agbd_prediction/agbd_t_se_a6',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0011/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0011/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0011/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0011/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0011/agbd_prediction/response_limit_flag_a1',
#  'BEAM0011/agbd_prediction/response_limit_flag_a10',
#  'BEAM0011/agbd_prediction/response_limit_flag_a2',
#  'BEAM0011/agbd_prediction/response_limit_flag_a3',
#  'BEAM0011/agbd_prediction/response_limit_flag_a4',
#  'BEAM0011/agbd_prediction/response_limit_flag_a5',
#  'BEAM0011/agbd_prediction/response_limit_flag_a6',
#  'BEAM0011/agbd_prediction/selected_mode_a1',
#  'BEAM0011/agbd_prediction/selected_mode_a10',
#  'BEAM0011/agbd_prediction/selected_mode_a2',
#  'BEAM0011/agbd_prediction/selected_mode_a3',
#  'BEAM0011/agbd_prediction/selected_mode_a4',
#  'BEAM0011/agbd_prediction/selected_mode_a5',
#  'BEAM0011/agbd_prediction/selected_mode_a6',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a1',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a10',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a2',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a3',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a4',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a5',
#  'BEAM0011/agbd_prediction/selected_mode_flag_a6',
#  'BEAM0011/agbd_prediction/shot_number',
#  'BEAM0011/agbd_prediction/xvar_a1',
#  'BEAM0011/agbd_prediction/xvar_a10',
#  'BEAM0011/agbd_prediction/xvar_a2',
#  'BEAM0011/agbd_prediction/xvar_a3',
#  'BEAM0011/agbd_prediction/xvar_a4',
#  'BEAM0011/agbd_prediction/xvar_a5',
#  'BEAM0011/agbd_prediction/xvar_a6',
#  'BEAM0011/agbd_se',
#  'BEAM0011/agbd_t',
#  'BEAM0011/agbd_t_se',
#  'BEAM0011/algorithm_run_flag',
#  'BEAM0011/beam',
#  'BEAM0011/channel',
#  'BEAM0011/degrade_flag',
#  'BEAM0011/delta_time',
#  'BEAM0011/elev_lowestmode',
#  'BEAM0011/geolocation/elev_lowestmode_a1',
#  'BEAM0011/geolocation/elev_lowestmode_a10',
#  'BEAM0011/geolocation/elev_lowestmode_a2',
#  'BEAM0011/geolocation/elev_lowestmode_a3',
#  'BEAM0011/geolocation/elev_lowestmode_a4',
#  'BEAM0011/geolocation/elev_lowestmode_a5',
#  'BEAM0011/geolocation/elev_lowestmode_a6',
#  'BEAM0011/geolocation/lat_lowestmode_a1',
#  'BEAM0011/geolocation/lat_lowestmode_a10',
#  'BEAM0011/geolocation/lat_lowestmode_a2',
#  'BEAM0011/geolocation/lat_lowestmode_a3',
#  'BEAM0011/geolocation/lat_lowestmode_a4',
#  'BEAM0011/geolocation/lat_lowestmode_a5',
#  'BEAM0011/geolocation/lat_lowestmode_a6',
#  'BEAM0011/geolocation/lon_lowestmode_a1',
#  'BEAM0011/geolocation/lon_lowestmode_a10',
#  'BEAM0011/geolocation/lon_lowestmode_a2',
#  'BEAM0011/geolocation/lon_lowestmode_a3',
#  'BEAM0011/geolocation/lon_lowestmode_a4',
#  'BEAM0011/geolocation/lon_lowestmode_a5',
#  'BEAM0011/geolocation/lon_lowestmode_a6',
#  'BEAM0011/geolocation/sensitivity_a1',
#  'BEAM0011/geolocation/sensitivity_a10',
#  'BEAM0011/geolocation/sensitivity_a2',
#  'BEAM0011/geolocation/sensitivity_a3',
#  'BEAM0011/geolocation/sensitivity_a4',
#  'BEAM0011/geolocation/sensitivity_a6',
#  'BEAM0011/geolocation/stale_return_flag',
#  'BEAM0011/l2_quality_flag',
#  'BEAM0011/l4_quality_flag',
#  'BEAM0011/land_cover_data/landsat_treecover',
#  'BEAM0011/land_cover_data/landsat_water_persistence',
#  'BEAM0011/land_cover_data/leaf_off_doy',
#  'BEAM0011/land_cover_data/leaf_off_flag',
#  'BEAM0011/land_cover_data/leaf_on_cycle',
#  'BEAM0011/land_cover_data/leaf_on_doy',
#  'BEAM0011/land_cover_data/pft_class',
#  'BEAM0011/land_cover_data/region_class',
#  'BEAM0011/land_cover_data/urban_focal_window_size',
#  'BEAM0011/land_cover_data/urban_proportion',
#  'BEAM0011/lat_lowestmode',
#  'BEAM0011/lon_lowestmode',
#  'BEAM0011/master_frac',
#  'BEAM0011/master_int',
#  'BEAM0011/predict_stratum',
#  'BEAM0011/predictor_limit_flag',
#  'BEAM0011/response_limit_flag',
#  'BEAM0011/selected_algorithm',
#  'BEAM0011/selected_mode',
#  'BEAM0011/selected_mode_flag',
#  'BEAM0011/sensitivity',
#  'BEAM0011/solar_elevation',
#  'BEAM0011/surface_flag',
#  'BEAM0011/xvar',
#  'BEAM0101/agbd',
#  'BEAM0101/agbd_pi_lower',
#  'BEAM0101/agbd_pi_upper',
#  'BEAM0101/agbd_prediction/agbd_a1',
#  'BEAM0101/agbd_prediction/agbd_a10',
#  'BEAM0101/agbd_prediction/agbd_a2',
#  'BEAM0101/agbd_prediction/agbd_a3',
#  'BEAM0101/agbd_prediction/agbd_a4',
#  'BEAM0101/agbd_prediction/agbd_a5',
#  'BEAM0101/agbd_prediction/agbd_a6',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0101/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0101/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0101/agbd_prediction/agbd_se_a1',
#  'BEAM0101/agbd_prediction/agbd_se_a10',
#  'BEAM0101/agbd_prediction/agbd_se_a2',
#  'BEAM0101/agbd_prediction/agbd_se_a3',
#  'BEAM0101/agbd_prediction/agbd_se_a4',
#  'BEAM0101/agbd_prediction/agbd_se_a5',
#  'BEAM0101/agbd_prediction/agbd_se_a6',
#  'BEAM0101/agbd_prediction/agbd_t_a1',
#  'BEAM0101/agbd_prediction/agbd_t_a10',
#  'BEAM0101/agbd_prediction/agbd_t_a2',
#  'BEAM0101/agbd_prediction/agbd_t_a3',
#  'BEAM0101/agbd_prediction/agbd_t_a4',
#  'BEAM0101/agbd_prediction/agbd_t_a5',
#  'BEAM0101/agbd_prediction/agbd_t_a6',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0101/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0101/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0101/agbd_prediction/agbd_t_se_a1',
#  'BEAM0101/agbd_prediction/agbd_t_se_a10',
#  'BEAM0101/agbd_prediction/agbd_t_se_a2',
#  'BEAM0101/agbd_prediction/agbd_t_se_a3',
#  'BEAM0101/agbd_prediction/agbd_t_se_a4',
#  'BEAM0101/agbd_prediction/agbd_t_se_a5',
#  'BEAM0101/agbd_prediction/agbd_t_se_a6',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0101/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0101/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0101/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0101/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0101/agbd_prediction/response_limit_flag_a1',
#  'BEAM0101/agbd_prediction/response_limit_flag_a10',
#  'BEAM0101/agbd_prediction/response_limit_flag_a2',
#  'BEAM0101/agbd_prediction/response_limit_flag_a3',
#  'BEAM0101/agbd_prediction/response_limit_flag_a4',
#  'BEAM0101/agbd_prediction/response_limit_flag_a5',
#  'BEAM0101/agbd_prediction/response_limit_flag_a6',
#  'BEAM0101/agbd_prediction/selected_mode_a1',
#  'BEAM0101/agbd_prediction/selected_mode_a10',
#  'BEAM0101/agbd_prediction/selected_mode_a2',
#  'BEAM0101/agbd_prediction/selected_mode_a3',
#  'BEAM0101/agbd_prediction/selected_mode_a4',
#  'BEAM0101/agbd_prediction/selected_mode_a5',
#  'BEAM0101/agbd_prediction/selected_mode_a6',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a1',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a10',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a2',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a3',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a4',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a5',
#  'BEAM0101/agbd_prediction/selected_mode_flag_a6',
#  'BEAM0101/agbd_prediction/shot_number',
#  'BEAM0101/agbd_prediction/xvar_a1',
#  'BEAM0101/agbd_prediction/xvar_a10',
#  'BEAM0101/agbd_prediction/xvar_a2',
#  'BEAM0101/agbd_prediction/xvar_a3',
#  'BEAM0101/agbd_prediction/xvar_a4',
#  'BEAM0101/agbd_prediction/xvar_a5',
#  'BEAM0101/agbd_prediction/xvar_a6',
#  'BEAM0101/agbd_se',
#  'BEAM0101/agbd_t',
#  'BEAM0101/agbd_t_se',
#  'BEAM0101/algorithm_run_flag',
#  'BEAM0101/beam',
#  'BEAM0101/channel',
#  'BEAM0101/degrade_flag',
#  'BEAM0101/delta_time',
#  'BEAM0101/elev_lowestmode',
#  'BEAM0101/geolocation/elev_lowestmode_a1',
#  'BEAM0101/geolocation/elev_lowestmode_a10',
#  'BEAM0101/geolocation/elev_lowestmode_a2',
#  'BEAM0101/geolocation/elev_lowestmode_a3',
#  'BEAM0101/geolocation/elev_lowestmode_a4',
#  'BEAM0101/geolocation/elev_lowestmode_a5',
#  'BEAM0101/geolocation/elev_lowestmode_a6',
#  'BEAM0101/geolocation/lat_lowestmode_a1',
#  'BEAM0101/geolocation/lat_lowestmode_a10',
#  'BEAM0101/geolocation/lat_lowestmode_a2',
#  'BEAM0101/geolocation/lat_lowestmode_a3',
#  'BEAM0101/geolocation/lat_lowestmode_a4',
#  'BEAM0101/geolocation/lat_lowestmode_a5',
#  'BEAM0101/geolocation/lat_lowestmode_a6',
#  'BEAM0101/geolocation/lon_lowestmode_a1',
#  'BEAM0101/geolocation/lon_lowestmode_a10',
#  'BEAM0101/geolocation/lon_lowestmode_a2',
#  'BEAM0101/geolocation/lon_lowestmode_a3',
#  'BEAM0101/geolocation/lon_lowestmode_a4',
#  'BEAM0101/geolocation/lon_lowestmode_a5',
#  'BEAM0101/geolocation/lon_lowestmode_a6',
#  'BEAM0101/geolocation/sensitivity_a1',
#  'BEAM0101/geolocation/sensitivity_a10',
#  'BEAM0101/geolocation/sensitivity_a2',
#  'BEAM0101/geolocation/sensitivity_a3',
#  'BEAM0101/geolocation/sensitivity_a4',
#  'BEAM0101/geolocation/sensitivity_a6',
#  'BEAM0101/geolocation/stale_return_flag',
#  'BEAM0101/l2_quality_flag',
#  'BEAM0101/l4_quality_flag',
#  'BEAM0101/land_cover_data/landsat_treecover',
#  'BEAM0101/land_cover_data/landsat_water_persistence',
#  'BEAM0101/land_cover_data/leaf_off_doy',
#  'BEAM0101/land_cover_data/leaf_off_flag',
#  'BEAM0101/land_cover_data/leaf_on_cycle',
#  'BEAM0101/land_cover_data/leaf_on_doy',
#  'BEAM0101/land_cover_data/pft_class',
#  'BEAM0101/land_cover_data/region_class',
#  'BEAM0101/land_cover_data/urban_focal_window_size',
#  'BEAM0101/land_cover_data/urban_proportion',
#  'BEAM0101/lat_lowestmode',
#  'BEAM0101/lon_lowestmode',
#  'BEAM0101/master_frac',
#  'BEAM0101/master_int',
#  'BEAM0101/predict_stratum',
#  'BEAM0101/predictor_limit_flag',
#  'BEAM0101/response_limit_flag',
#  'BEAM0101/selected_algorithm',
#  'BEAM0101/selected_mode',
#  'BEAM0101/selected_mode_flag',
#  'BEAM0101/sensitivity',
#  'BEAM0101/solar_elevation',
#  'BEAM0101/surface_flag',
#  'BEAM0101/xvar',
#  'BEAM0110/agbd',
#  'BEAM0110/agbd_pi_lower',
#  'BEAM0110/agbd_pi_upper',
#  'BEAM0110/agbd_prediction/agbd_a1',
#  'BEAM0110/agbd_prediction/agbd_a10',
#  'BEAM0110/agbd_prediction/agbd_a2',
#  'BEAM0110/agbd_prediction/agbd_a3',
#  'BEAM0110/agbd_prediction/agbd_a4',
#  'BEAM0110/agbd_prediction/agbd_a5',
#  'BEAM0110/agbd_prediction/agbd_a6',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a1',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a10',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a2',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a3',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a4',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a5',
#  'BEAM0110/agbd_prediction/agbd_pi_lower_a6',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a1',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a10',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a2',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a3',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a4',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a5',
#  'BEAM0110/agbd_prediction/agbd_pi_upper_a6',
#  'BEAM0110/agbd_prediction/agbd_se_a1',
#  'BEAM0110/agbd_prediction/agbd_se_a10',
#  'BEAM0110/agbd_prediction/agbd_se_a2',
#  'BEAM0110/agbd_prediction/agbd_se_a3',
#  'BEAM0110/agbd_prediction/agbd_se_a4',
#  'BEAM0110/agbd_prediction/agbd_se_a5',
#  'BEAM0110/agbd_prediction/agbd_se_a6',
#  'BEAM0110/agbd_prediction/agbd_t_a1',
#  'BEAM0110/agbd_prediction/agbd_t_a10',
#  'BEAM0110/agbd_prediction/agbd_t_a2',
#  'BEAM0110/agbd_prediction/agbd_t_a3',
#  'BEAM0110/agbd_prediction/agbd_t_a4',
#  'BEAM0110/agbd_prediction/agbd_t_a5',
#  'BEAM0110/agbd_prediction/agbd_t_a6',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a1',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a10',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a2',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a3',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a4',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a5',
#  'BEAM0110/agbd_prediction/agbd_t_pi_lower_a6',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a1',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a10',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a2',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a3',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a4',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a5',
#  'BEAM0110/agbd_prediction/agbd_t_pi_upper_a6',
#  'BEAM0110/agbd_prediction/agbd_t_se_a1',
#  'BEAM0110/agbd_prediction/agbd_t_se_a10',
#  'BEAM0110/agbd_prediction/agbd_t_se_a2',
#  'BEAM0110/agbd_prediction/agbd_t_se_a3',
#  'BEAM0110/agbd_prediction/agbd_t_se_a4',
#  'BEAM0110/agbd_prediction/agbd_t_se_a5',
#  'BEAM0110/agbd_prediction/agbd_t_se_a6',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a1',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a10',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a2',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a3',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a4',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a5',
#  'BEAM0110/agbd_prediction/algorithm_run_flag_a6',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a1',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a10',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a2',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a3',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a4',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a5',
#  'BEAM0110/agbd_prediction/l2_quality_flag_a6',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a1',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a10',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a2',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a3',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a4',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a5',
#  'BEAM0110/agbd_prediction/l4_quality_flag_a6',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a1',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a10',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a2',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a3',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a4',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a5',
#  'BEAM0110/agbd_prediction/predictor_limit_flag_a6',
#  'BEAM0110/agbd_prediction/response_limit_flag_a1',
#  'BEAM0110/agbd_prediction/response_limit_flag_a10',
#  'BEAM0110/agbd_prediction/response_limit_flag_a2',
#  'BEAM0110/agbd_prediction/response_limit_flag_a3',
#  'BEAM0110/agbd_prediction/response_limit_flag_a4',
#  'BEAM0110/agbd_prediction/response_limit_flag_a5',
#  'BEAM0110/agbd_prediction/response_limit_flag_a6',
#  'BEAM0110/agbd_prediction/selected_mode_a1',
#  'BEAM0110/agbd_prediction/selected_mode_a10',
#  'BEAM0110/agbd_prediction/selected_mode_a2',
#  'BEAM0110/agbd_prediction/selected_mode_a3',
#  'BEAM0110/agbd_prediction/selected_mode_a4',
#  'BEAM0110/agbd_prediction/selected_mode_a5',
#  'BEAM0110/agbd_prediction/selected_mode_a6',
#  'BEAM0110/agbd_prediction/selected_mode_flag_a1',
#  ...]

# %%
vars.avail(options=True)
# Out:
# var_list inputs: model_data, pft_lut, region_lut, agbd, agbd_pi_lower, agbd_pi_upper, agbd_a1, agbd_a10, agbd_a2, agbd_a3, agbd_a4, agbd_a5, agbd_a6, agbd_pi_lower_a1, agbd_pi_lower_a10, agbd_pi_lower_a2, agbd_pi_lower_a3, agbd_pi_lower_a4, agbd_pi_lower_a5, agbd_pi_lower_a6, agbd_pi_upper_a1, agbd_pi_upper_a10, agbd_pi_upper_a2, agbd_pi_upper_a3, agbd_pi_upper_a4, agbd_pi_upper_a5, agbd_pi_upper_a6, agbd_se_a1, agbd_se_a10, agbd_se_a2, agbd_se_a3, agbd_se_a4, agbd_se_a5, agbd_se_a6, agbd_t_a1, agbd_t_a10, agbd_t_a2, agbd_t_a3, agbd_t_a4, agbd_t_a5, agbd_t_a6, agbd_t_pi_lower_a1, agbd_t_pi_lower_a10, agbd_t_pi_lower_a2, agbd_t_pi_lower_a3, agbd_t_pi_lower_a4, agbd_t_pi_lower_a5, agbd_t_pi_lower_a6, agbd_t_pi_upper_a1, agbd_t_pi_upper_a10, agbd_t_pi_upper_a2, agbd_t_pi_upper_a3, agbd_t_pi_upper_a4, agbd_t_pi_upper_a5, agbd_t_pi_upper_a6, agbd_t_se_a1, agbd_t_se_a10, agbd_t_se_a2, agbd_t_se_a3, agbd_t_se_a4, agbd_t_se_a5, agbd_t_se_a6, algorithm_run_flag_a1, algorithm_run_flag_a10, algorithm_run_flag_a2, algorithm_run_flag_a3, algorithm_run_flag_a4, algorithm_run_flag_a5, algorithm_run_flag_a6, l2_quality_flag_a1, l2_quality_flag_a10, l2_quality_flag_a2, l2_quality_flag_a3, l2_quality_flag_a4, l2_quality_flag_a5, l2_quality_flag_a6, l4_quality_flag_a1, l4_quality_flag_a10, l4_quality_flag_a2, l4_quality_flag_a3, l4_quality_flag_a4, l4_quality_flag_a5, l4_quality_flag_a6, predictor_limit_flag_a1, predictor_limit_flag_a10, predictor_limit_flag_a2, predictor_limit_flag_a3, predictor_limit_flag_a4, predictor_limit_flag_a5, predictor_limit_flag_a6, response_limit_flag_a1, response_limit_flag_a10, response_limit_flag_a2, response_limit_flag_a3, response_limit_flag_a4, response_limit_flag_a5, response_limit_flag_a6, selected_mode_a1, selected_mode_a10, selected_mode_a2, selected_mode_a3, selected_mode_a4, selected_mode_a5, selected_mode_a6, selected_mode_flag_a1, selected_mode_flag_a10, selected_mode_flag_a2, selected_mode_flag_a3, selected_mode_flag_a4, selected_mode_flag_a5, selected_mode_flag_a6, shot_number, xvar_a1, xvar_a10, xvar_a2, xvar_a3, xvar_a4, xvar_a5, xvar_a6, agbd_se, agbd_t, agbd_t_se, algorithm_run_flag, beam, channel, degrade_flag, delta_time, elev_lowestmode, elev_lowestmode_a1, elev_lowestmode_a10, elev_lowestmode_a2, elev_lowestmode_a3, elev_lowestmode_a4, elev_lowestmode_a5, elev_lowestmode_a6, lat_lowestmode_a1, lat_lowestmode_a10, lat_lowestmode_a2, lat_lowestmode_a3, lat_lowestmode_a4, lat_lowestmode_a5, lat_lowestmode_a6, lon_lowestmode_a1, lon_lowestmode_a10, lon_lowestmode_a2, lon_lowestmode_a3, lon_lowestmode_a4, lon_lowestmode_a5, lon_lowestmode_a6, sensitivity_a1, sensitivity_a10, sensitivity_a2, sensitivity_a3, sensitivity_a4, sensitivity_a6, stale_return_flag, l2_quality_flag, l4_quality_flag, landsat_treecover, landsat_water_persistence, leaf_off_doy, leaf_off_flag, leaf_on_cycle, leaf_on_doy, pft_class, region_class, urban_focal_window_size, urban_proportion, lat_lowestmode, lon_lowestmode, master_frac, master_int, predict_stratum, predictor_limit_flag, response_limit_flag, selected_algorithm, selected_mode, selected_mode_flag, sensitivity, solar_elevation, surface_flag, xvar
# keyword_list and beam_list inputs: ANCILLARY, BEAM0000, BEAM0001, BEAM0010, BEAM0011, BEAM0101, BEAM0110, BEAM1000, BEAM1011, agbd_prediction, geolocation, land_cover_data, none

# %%
vars.append(var_list=["shot_number","beam","lat_lowestmode_a1","lon_lowestmode_a1"])

# %%
vars.wanted
# Out:
# {'shot_number': ['BEAM0000/agbd_prediction/shot_number',
#   'BEAM0001/agbd_prediction/shot_number',
#   'BEAM0010/agbd_prediction/shot_number',
#   'BEAM0011/agbd_prediction/shot_number',
#   'BEAM0101/agbd_prediction/shot_number',
#   'BEAM0110/agbd_prediction/shot_number',
#   'BEAM1000/agbd_prediction/shot_number',
#   'BEAM1011/agbd_prediction/shot_number'],
#  'beam': ['BEAM0000/beam',
#   'BEAM0001/beam',
#   'BEAM0010/beam',
#   'BEAM0011/beam',
#   'BEAM0101/beam',
#   'BEAM0110/beam',
#   'BEAM1000/beam',
#   'BEAM1011/beam'],
#  'lat_lowestmode_a1': ['BEAM0000/geolocation/lat_lowestmode_a1',
#   'BEAM0001/geolocation/lat_lowestmode_a1',
#   'BEAM0010/geolocation/lat_lowestmode_a1',
#   'BEAM0011/geolocation/lat_lowestmode_a1',
#   'BEAM0101/geolocation/lat_lowestmode_a1',
#   'BEAM0110/geolocation/lat_lowestmode_a1',
#   'BEAM1000/geolocation/lat_lowestmode_a1',
#   'BEAM1011/geolocation/lat_lowestmode_a1'],
#  'lon_lowestmode_a1': ['BEAM0000/geolocation/lon_lowestmode_a1',
#   'BEAM0001/geolocation/lon_lowestmode_a1',
#   'BEAM0010/geolocation/lon_lowestmode_a1',
#   'BEAM0011/geolocation/lon_lowestmode_a1',
#   'BEAM0101/geolocation/lon_lowestmode_a1',
#   'BEAM0110/geolocation/lon_lowestmode_a1',
#   'BEAM1000/geolocation/lon_lowestmode_a1',
#   'BEAM1011/geolocation/lon_lowestmode_a1']}

# %%
vars.remove(all=True)

# %%
vars.append(var_list=["shot_number","beam","lat_lowestmode_a1","lon_lowestmode_a1"], keyword_list=["BEAM0010"])

# %%
vars.wanted
# Out:
# {'shot_number': ['BEAM0010/agbd_prediction/shot_number'],
#  'beam': ['BEAM0010/beam'],
#  'lat_lowestmode_a1': ['BEAM0010/geolocation/lat_lowestmode_a1'],
#  'lon_lowestmode_a1': ['BEAM0010/geolocation/lon_lowestmode_a1']}
